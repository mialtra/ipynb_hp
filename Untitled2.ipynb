# %%
import pandas as pd
sample_data=pd.read_csv("BIKE DETAILS.csv")
sample_data
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# 0     1st owner        350                NaN
# 1     1st owner       5650                NaN
# 2     1st owner      12000           148114.0
# 3     1st owner      23000            89643.0
# 4     2nd owner      21000                NaN
# ...         ...        ...                ...
# 1056  1st owner     500000            52000.0
# 1057  1st owner      33000            51000.0
# 1058  2nd owner      35000            57000.0
# 1059  1st owner      53000            58000.0
# 1060  1st owner      92233            75000.0
#
# [1061 rows x 7 columns]

# %%
filtered_data = sample_data[(sample_data['km_driven'].between (10000,30000)) & (sample_data['name'].str.contains('Honda'))      ]
filtered_data
# Out:
#                         name  selling_price  year seller_type      owner  \
# 6       Honda CB Hornet 160R          78500  2018  Individual  1st owner
# 11                Honda Navi          28000  2016  Individual  2nd owner
# 16        Hero Honda Glamour          25000  2006  Individual  1st owner
# 21    Honda Navi [2016-2017]          26000  2016  Individual  1st owner
# 22            Honda Activa i          32000  2013  Individual  2nd owner
# ...                      ...            ...   ...         ...        ...
# 998     Honda CB Hornet 160R          60000  2018  Individual  1st owner
# 1028        Honda CB Trigger          42000  2015  Individual  1st owner
# 1036           Honda Karizma          35000  2013  Individual  1st owner
# 1037        Honda Activa 125          35000  2018  Individual  1st owner
# 1042          Honda CB Shine          30000  2015  Individual  1st owner
#
#       km_driven  ex_showroom_price
# 6         17000            87719.0
# 11        10000            47255.0
# 16        27000                NaN
# 21        17450            44389.0
# 22        20696            53900.0
# ...         ...                ...
# 998       15000            87000.0
# 1028      12000            73000.0
# 1036      30000           105000.0
# 1037      24000            57000.0
# 1042      30000            58000.0
#
# [119 rows x 7 columns]

# %%
X = filtered_data['km_driven']
y = filtered_data['selling_price']

# %%
# Setup setting terkait dengan plotting
import numpy as np                 # import numpy (mathematical operation)
import matplotlib.pyplot as plt    # import package untuk plotting
from matplotlib import rcParams    # runtime configuration (rc)
rcParams['figure.figsize']    = (14,7)   # untuk membuat visualisasi lebih baik, modif parameter dibawah ini
rcParams['axes.spines.top']   = False
rcParams['axes.spines.right'] = False

# %%
# plotting data
plt.scatter(X, y, s=50, c='#087E8B', alpha=0.65) # s=ukuranMarker, c=color, alpha=transparency
plt.title('Source data', size=20)                 # size= ukuran font
plt.xlabel('Engine Size', size=14)
plt.ylabel('Price ($)', size=14)
plt.show()
