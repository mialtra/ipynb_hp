# %%
import pandas as pd
from sklearn.metrics import r2_score
from datetime import datetime
import numpy as np

import sklearn
import matplotlib.pyplot as plt

# %%
# load dataset
data = pd.read_csv('Data_electricityConsumption_weather_4.csv')
data
# Out:
#                             TIME  Temperature  humidity  Wind_Speed  \
# 0      2017-01-01 00:00:00+01:00         6.00        88           2
# 1      2017-01-01 01:00:00+01:00         6.00        95           1
# 2      2017-01-01 02:00:00+01:00         6.00        88           2
# 3      2017-01-01 03:00:00+01:00         4.00        95           2
# 4      2017-01-01 04:00:00+01:00         5.00        95           2
# ...                          ...          ...       ...         ...
# 17515  2018-12-30 08:00:00+01:00         2.51        95           3
# 17516  2018-12-30 09:00:00+01:00         2.00        95           3
# 17517  2018-12-30 10:00:00+01:00         4.49        81           3
# 17518  2018-12-30 11:00:00+01:00         9.51        65           3
# 17519  2018-12-30 12:00:00+01:00        13.01        53           3
#
#        Rain_rate  Electricity_Consumption
# 0            0.0                    24635
# 1            0.0                    23627
# ...

# %%
dataku = pd.DataFrame(data)
#visualisasi data
dataku.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17520 entries, 0 to 17519
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   TIME                     17520 non-null  object
#  1   Temperature              17520 non-null  float64
#  2   humidity                 17520 non-null  int64
#  3   Wind_Speed               17520 non-null  int64
#  4   Rain_rate                17520 non-null  float64
#  5   Electricity_Consumption  17520 non-null  int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 821.4+ KB

# %%
plt.scatter(dataku.Temperature,dataku.Electricity_Consumption)
plt.xlabel("Temperature")
plt.ylabel("Electricity_Consumption")
plt.title ("Perbandingan Temperature terhadap Electricity_Consumption")
plt.show()

# %%
X =dataku.Temperature.values
y = dataku.Electricity_Consumption.values
X
# Out:
# array([ 6.  ,  6.  ,  6.  , ...,  4.49,  9.51, 13.01])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X,y, test_size = 0.1, random_state=0)

# %%
X_train= X_train.reshape(-1, 1)
X_test = X_test.reshape(-1, 1)

y_train= y_train.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)

# %%
#fitting
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
plt.figure(figsize=(10,8))
plt.scatter(X_train,y_train,color = 'blue')
plt.plot(X_train,regressor.predict(X_train),color='red')
plt.xlabel("Temperature")
plt.ylabel("Electricity_Consumption")
plt.title ("Perbandingan Temperature terhadap Electricity_Consumption")
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.scatter(X_test,y_test,color = 'green')
plt.plot(X_train,regressor.predict(X_train),color='red')
plt.xlabel("Temperature")
plt.ylabel("Electricity_Consumption")
plt.title ("Perbandingan Temperature terhadap Electricity_Consumption")
plt.show()

# %%
coef = regressor.coef_[0]
intercept = regressor.intercept_
print("Persamaan garis: y = {}x + {}".format(coef, intercept))
# Out:
# Persamaan garis: y = [-21.35846253]x + [29572.89135982]

# %%
df.corr()

# %%
r2_temperature = r2_score(df['Electricity_Consumption'], df['Temperature'])
r2_humidity = r2_score(df['Electricity_Consumption'], df['humidity'])
r2_windspeed = r2_score(df['Electricity_Consumption'], df['Wind_Speed'])
r2_rainrate = r2_score(df['Electricity_Consumption'], df['Rain_rate'])

# %%
print ('R2 Score Temperature = ',r2_temperature)
print ('R2 Score Temperature = ',r2_humidity)
print ('R2 Score Temperature = ',r2_windspeed)
print ('R2 Score Temperature = ',r2_rainrate)

# %%
features = df[['Temperature', 'humidity', 'Wind_Speed', 'Rain_rate']]
target = data['Electricity_Consumption']

# %%
# calculate the r2 score
r2_score_2 = r2_score(target, features)

# print the r2 score
print('r2 score:', r2_score_2)
