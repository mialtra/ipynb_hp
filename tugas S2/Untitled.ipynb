# %%
import pandas as pd
from sklearn.metrics import r2_score
from datetime import datetime
import numpy as np

import sklearn
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
# load dataset
data = pd.read_csv('Data_electricityConsumption_weather_4.csv')
data
# Out:
#                             TIME  Temperature  humidity  Wind_Speed  \
# 0      2017-01-01 00:00:00+01:00         6.00        88           2
# 1      2017-01-01 01:00:00+01:00         6.00        95           1
# 2      2017-01-01 02:00:00+01:00         6.00        88           2
# 3      2017-01-01 03:00:00+01:00         4.00        95           2
# 4      2017-01-01 04:00:00+01:00         5.00        95           2
# ...                          ...          ...       ...         ...
# 17515  2018-12-30 08:00:00+01:00         2.51        95           3
# 17516  2018-12-30 09:00:00+01:00         2.00        95           3
# 17517  2018-12-30 10:00:00+01:00         4.49        81           3
# 17518  2018-12-30 11:00:00+01:00         9.51        65           3
# 17519  2018-12-30 12:00:00+01:00        13.01        53           3
#
#        Rain_rate  Electricity_Consumption
# 0            0.0                    24635
# 1            0.0                    23627
# ...

# %%
dataku = pd.DataFrame(data)

# %%
# convert datetime column to pandas DatetimeIndex
data['TIME'] = pd.to_datetime(data['TIME'], utc=True)
# extract hour into new column
data['hour'] = data['TIME'].dt.hour

# %% [markdown]
# for hour in range(24):
#     #print("variabel_"+(str(hour)))
#     filtered_df+(str(hour)) = data.loc[data['hour'] ==hour]

# %%
filtered_df_0 = data.loc[data['hour'] ==0]
filtered_df_1 = data.loc[data['hour'] ==1]
filtered_df_2 = data.loc[data['hour'] ==2]
filtered_df_3 = data.loc[data['hour'] ==3]
filtered_df_4 = data.loc[data['hour'] ==4]
filtered_df_5 = data.loc[data['hour'] ==5]
filtered_df_6 = data.loc[data['hour'] ==6]
filtered_df_7 = data.loc[data['hour'] ==7]
filtered_df_8 = data.loc[data['hour'] ==8]
filtered_df_9 = data.loc[data['hour'] ==9]
filtered_df_10 = data.loc[data['hour'] ==10]
filtered_df_11 = data.loc[data['hour'] ==11]
filtered_df_12 = data.loc[data['hour'] ==12]
filtered_df_13 = data.loc[data['hour'] ==13]
filtered_df_14 = data.loc[data['hour'] ==14]
filtered_df_15 = data.loc[data['hour'] ==15]
filtered_df_16 = data.loc[data['hour'] ==16]
filtered_df_17 = data.loc[data['hour'] ==17]
filtered_df_18 = data.loc[data['hour'] ==18]
filtered_df_19 = data.loc[data['hour'] ==19]
filtered_df_20 = data.loc[data['hour'] ==20]
filtered_df_21 = data.loc[data['hour'] ==21]
filtered_df_22 = data.loc[data['hour'] ==22]
filtered_df_23 = data.loc[data['hour'] ==23]

# %%
filtered_df_23
# Out:
#                            TIME  Temperature  humidity  Wind_Speed  Rain_rate  \
# 0     2016-12-31 23:00:00+00:00         6.00        88           2        0.0
# 24    2017-01-01 23:00:00+00:00         3.00        81           2        0.0
# 48    2017-01-02 23:00:00+00:00         6.00        88           2        0.0
# 72    2017-01-03 23:00:00+00:00         6.00        95           2        0.0
# 96    2017-01-04 23:00:00+00:00         8.00        88           3        0.0
# ...                         ...          ...       ...         ...        ...
# 17411 2018-12-25 23:00:00+00:00         7.99        88           2        0.0
# 17435 2018-12-26 23:00:00+00:00         9.99        88           3        0.0
# 17459 2018-12-27 23:00:00+00:00         9.01        88           2        0.0
# 17483 2018-12-28 23:00:00+00:00         8.99        88           3        0.0
# 17507 2018-12-29 23:00:00+00:00         4.49        88           3        0.0
#
# ...

# %%
plt.scatter(filtered_df_23.Temperature,filtered_df_23.Electricity_Consumption)
plt.xlabel("Temperature")
plt.ylabel("Electricity_Consumption")
plt.title ("Perbandingan Temperature terhadap Electricity_Consumption")
plt.show()

# %%
X =filtered_df_23.Temperature.values
y = filtered_df_23.Electricity_Consumption.values


X_train, X_test, y_train, y_test= train_test_split(X,y, test_size = 0.2, random_state=0)

# %%
X_train= X_train.reshape(-1, 1)
X_test = X_test.reshape(-1, 1)

y_train= y_train.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)

# %%
#fitting
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
plt.figure(figsize=(10,8))
plt.scatter(X_train,y_train,color = 'blue')
plt.plot(X_train,regressor.predict(X_train),color='red')
plt.xlabel("Temperature")
plt.ylabel("Electricity_Consumption")
plt.title ("Perbandingan Temperature terhadap Electricity_Consumption")
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.scatter(X_test,y_test,color = 'green')
plt.plot(X_train,regressor.predict(X_train),color='red')
plt.xlabel("Temperature")
plt.ylabel("Electricity_Consumption")
plt.title ("Perbandingan Temperature terhadap Electricity_Consumption")
plt.show()

# %%
coef = regressor.coef_[0]
intercept = regressor.intercept_

# %%
print("Persamaan garis: y = {}x + {}".format(coef, intercept))
# Out:
# Persamaan garis: y = [161.77178575]x + [26600.09781152]
